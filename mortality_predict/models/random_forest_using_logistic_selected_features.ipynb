# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    average_precision_score,
    precision_recall_curve,
)
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
import warnings

# %% [markdown]
# ## 1. Load Processed Data (feature engineering; 24h; aggregation)

# %%
df_agg = pd.read_csv('../../data/mimic_dataset_24h_aggregated.csv')
df_agg.head()
# Out:
#    gender  age  elixhauser  re_admission  Height_cm  Weight_kg  mechvent_mean  \
# 0       1   61           1             0     173.00      115.0       0.000000
# 1       1   92           4             1     163.00       68.5       0.000000
# 2       1   78           9             0     182.88       90.0       0.714286
# 3       1   56           4             0     178.00      119.3       0.000000
# 4       0   61           8             0     180.34       78.4       0.000000
#
#    mechvent_max  extubated_mean  extubated_max  ...  SOFA_min  SOFA_max  \
# 0             0             0.0              0  ...        13        13
# 1             0             0.0              0  ...         2         8
# 2             1             0.0              0  ...         5         8
# 3             0             0.0              0  ...         8         9
# 4             0             0.0              0  ...         9        11
#
#    SOFA_std  SOFA_last  SIRS_mean  SIRS_min  SIRS_max  SIRS_std  SIRS_last  \
# 0       NaN         13   1.000000         1         1       NaN          1
# 1  2.225395          5   2.285714         1         4  0.951190          2
# 2  0.975900          7   2.571429         2         3  0.534522          2
# 3  0.534522          9   2.000000         0         3  1.000000          0
# 4  0.707107         10   1.800000         1         2  0.447214          2
#
#    died_in_hosp
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1
#
# [5 rows x 326 columns]

# %%
df_selected = pd.read_csv('logistic_regression_selected_features.csv')
selected_features = df_selected['feature'].tolist()
df_selected.head()
# Out:
#             feature  coefficient  abs_coefficient
# 0               age     0.359537         0.359537
# 1        elixhauser     0.248693         0.248693
# 2    extubated_mean    -0.211579         0.211579
# 3  output_step_mean    -0.206943         0.206943
# 4           GCS_max    -0.200353         0.200353

# %% [markdown]
# ## 2. Define X and y

# %%
target_col = 'died_in_hosp'
y = df_agg[target_col].astype(int)
X = df_agg[selected_features]

# %%
print(f"class distribution:")
print(f"  died patients (1): {(y==1).sum()} ({(y==1).mean()*100:.1f}%)")
print(f"  survived patients (0): {(y==0).sum()} ({(y==0).mean()*100:.1f}%)")
# Out:
# class distribution:
#   died patients (1): 4784 (16.5%)
#   survived patients (0): 24276 (83.5%)

# %% [markdown]
# ## 3. Data Splitting
# - Divide the dataset into the training set and the test set, with an 80/20 ratio.
# - To ensure that the proportion of deceased/survived patients in the training set and the test set is consistent with the original data, `stratified sampling` is adopted.

# %%
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=test_size, 
    random_state=42, 
    stratify=y
)

print(f"Size of the training set: {X_train.shape}")
print(f"Size of the testing set: {X_test.shape}")
print(f"Training set mortality rate: {y_train.mean():.3f}")
print(f"Testing set mortality rate: {y_test.mean():.3f}")
# Out:
# Size of the training set: (23248, 85)
# Size of the testing set: (5812, 85)
# Training set mortality rate: 0.165
# Testing set mortality rate: 0.165

# %% [markdown]
# ## 4. Missing Value Imputation

# %% [markdown]
# - For numerical features, using the median is often more robust than the mean, as it is not affected by outliers. For categorical features, the mode can be used.
#
# - The imputation values are calculated only on the training set and then applied to both the training and testing sets to prevent data leakage.

# %%
print(f"Proportion of missing values:")
missing_proportion = (X.isnull().sum()/X.shape[0]).sort_values(ascending=False) 
print(missing_proportion)
# Out:
# Proportion of missing values:
# RR_std               0.032278
# PT_std               0.032278
# SpO2_std             0.032278
# Shock_Index_std      0.032278
# PTT_std              0.032278
#                        ...
# FiO2_100_last        0.000000
# INR_last             0.000000
# WBC_count_last       0.000000
# Sodium_max           0.000000
# MinuteVentil_last    0.000000
# Length: 85, dtype: float64

# %%
imputer = SimpleImputer(strategy='median')

X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# %% [markdown]
# ## 5. Feature Scaling
#
# Random Forest doesn't need feature scaling (tree-based models are scale-invariant)

# %% [markdown]
# ## 6. Random Forest Training and Hyperparameter Tuning

# %%
def objective(trial):
    """
    Optuna objective function for Random Forest hyperparameter optimization.
    Uses StratifiedKFold cross-validation and evaluates using AUCPR with overfitting penalty
    """
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'max_depth': trial.suggest_int('max_depth', 5, 30),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', 0.3, 0.5, 0.7]),
        'min_impurity_decrease': trial.suggest_float('min_impurity_decrease', 0.0, 0.01),  # regularization to reduce overfitting
        'max_samples': trial.suggest_float('max_samples', 0.6, 1.0),  # bootstrap sampling
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'class_weight': 'balanced',  # imbalanced data handling
        'bootstrap': True,
        'oob_score': True,  # Out-of-bag score
        'random_state': 42,
        'n_jobs': -1
    }
    
    # StratifiedKFold cross-validation
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    cv_scores_auc = []
    cv_scores_aucpr = []  # AUCPR is more relevant for imbalanced data
    train_scores = []  # monitor training performance for overfitting analysis
    
    for fold_idx, (train_idx, val_idx) in enumerate(cv.split(X_train_imputed, y_train)):
        X_fold_train = X_train_imputed[train_idx]
        y_fold_train = y_train.iloc[train_idx]
        X_fold_val = X_train_imputed[val_idx]
        y_fold_val = y_train.iloc[val_idx]
        
        model = RandomForestClassifier(**params)
        
        model.fit(X_fold_train, y_fold_train)
        
        y_train_proba = model.predict_proba(X_fold_train)[:, 1]
        y_val_proba = model.predict_proba(X_fold_val)[:, 1]
        
        train_auc = roc_auc_score(y_fold_train, y_train_proba)
        val_auc = roc_auc_score(y_fold_val, y_val_proba)
        val_aucpr = average_precision_score(y_fold_val, y_val_proba)  # main metric
        
        train_scores.append(train_auc)
        cv_scores_auc.append(val_auc)
        cv_scores_aucpr.append(val_aucpr)
        
        # Optuna pruning
        trial.report(val_aucpr, fold_idx)
        if trial.should_prune():
            raise optuna.TrialPruned()
    
    mean_cv_auc = np.mean(cv_scores_auc)
    mean_cv_aucpr = np.mean(cv_scores_aucpr)
    mean_train_score = np.mean(train_scores)
    
    # overfitting peanlty
    overfitting_penalty = abs(mean_train_score - mean_cv_auc)
    if overfitting_penalty > 0.05:  # threshold: 5%
        mean_cv_aucpr -= overfitting_penalty * 0.5  
    
    trial.set_user_attr('mean_train_auc', mean_train_score)
    trial.set_user_attr('mean_val_auc', mean_cv_auc)
    trial.set_user_attr('mean_val_aucpr', mean_cv_aucpr)
    trial.set_user_attr('overfitting_gap', overfitting_penalty)
    
    return mean_cv_aucpr

# %%
study = optuna.create_study(
    direction='maximize',  # maximize AUCPR
    sampler=optuna.samplers.TPESampler(seed=42),  # TPE sampler
    pruner=optuna.pruners.MedianPruner(  # Median pruner
        n_startup_trials=10,
        n_warmup_steps=2,
        interval_steps=1
    )
)

study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2025-10-20 21:01:25,499] A new study created in memory with name: no-name-fe5d66d9-2e1b-41bf-92f5-4df32e067d2d
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-20 21:02:17,178] Trial 0 finished with value: 0.47338052833047184 and parameters: {'n_estimators': 400, 'max_depth': 29, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 0.5, 'min_impurity_decrease': 0.007080725777960455, 'max_samples': 0.608233797718321, 'criterion': 'gini'}. Best is trial 0 with value: 0.47338052833047184.
# [I 2025-10-20 21:03:51,524] Trial 1 finished with value: 0.5321699795674222 and parameters: {'n_estimators': 300, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.5, 'min_impurity_decrease': 0.0029214464853521815, 'max_samples': 0.7465447373174767, 'criterion': 'entropy'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:04:45,382] Trial 2 finished with value: 0.49182387178276094 and parameters: {'n_estimators': 200, 'max_depth': 18, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 0.7, 'min_impurity_decrease': 0.008083973481164611, 'max_samples': 0.7218455076693483, 'criterion': 'entropy'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:05:10,083] Trial 3 finished with value: 0.4929694442875749 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'min_impurity_decrease': 0.005467102793432797, 'max_samples': 0.6739417822102108, 'criterion': 'gini'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:10:20,021] Trial 4 finished with value: 0.5051288274929365 and parameters: {'n_estimators': 1000, 'max_depth': 28, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_features': 0.7, 'min_impurity_decrease': 0.002713490317738959, 'max_samples': 0.9314950036607718, 'criterion': 'gini'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:10:48,177] Trial 5 finished with value: 0.4836744956118153 and parameters: {'n_estimators': 600, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'min_impurity_decrease': 0.007068573438476171, 'max_samples': 0.8916028672163949, 'criterion': 'gini'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:12:22,500] Trial 6 finished with value: 0.47379574735165225 and parameters: {'n_estimators': 400, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': 0.7, 'min_impurity_decrease': 0.006375574713552132, 'max_samples': 0.9548850970305306, 'criterion': 'gini'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:13:45,657] Trial 7 finished with value: 0.49776814062565333 and parameters: {'n_estimators': 800, 'max_depth': 24, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 'log2', 'min_impurity_decrease': 0.0003142918568673425, 'max_samples': 0.8545641645055122, 'criterion': 'entropy'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:17:06,716] Trial 8 finished with value: 0.4610677889067064 and parameters: {'n_estimators': 1000, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 0.7, 'min_impurity_decrease': 0.008081203795644169, 'max_samples': 0.8533615026041694, 'criterion': 'gini'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:17:19,375] Trial 9 finished with value: 0.49867352431301626 and parameters: {'n_estimators': 200, 'max_depth': 28, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'min_impurity_decrease': 0.008180147659224932, 'max_samples': 0.9442922333025374, 'criterion': 'entropy'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:17:47,685] Trial 10 finished with value: 0.5251986302509001 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.5, 'min_impurity_decrease': 0.003420450074048333, 'max_samples': 0.7649987625876574, 'criterion': 'entropy'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:18:15,441] Trial 11 finished with value: 0.5215990642048501 and parameters: {'n_estimators': 100, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.5, 'min_impurity_decrease': 0.0036669554371005584, 'max_samples': 0.7623935852452096, 'criterion': 'entropy'}. Best is trial 1 with value: 0.5321699795674222.
# [I 2025-10-20 21:18:35,949] Trial 12 finished with value: 0.5358966621316973 and parameters: {'n_estimators': 100, 'max_depth': 18, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.3, 'min_impurity_decrease': 0.0024080793750091006, 'max_samples': 0.7908135866984993, 'criterion': 'entropy'}. Best is trial 12 with value: 0.5358966621316973.
# [I 2025-10-20 21:20:03,895] Trial 13 finished with value: 0.5140357515654602 and parameters: {'n_estimators': 300, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.3, 'min_impurity_decrease': 0.0011851343197581737, 'max_samples': 0.8257480050732254, 'criterion': 'entropy'}. Best is trial 12 with value: 0.5358966621316973.
# [I 2025-10-20 21:20:46,797] Trial 14 finished with value: 0.5326002349547625 and parameters: {'n_estimators': 300, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0019822128908475664, 'max_samples': 0.684798303843239, 'criterion': 'entropy'}. Best is trial 12 with value: 0.5358966621316973.
# [I 2025-10-20 21:22:11,511] Trial 15 finished with value: 0.5366447413381628 and parameters: {'n_estimators': 600, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0014669446962087135, 'max_samples': 0.6684200543843214, 'criterion': 'entropy'}. Best is trial 15 with value: 0.5366447413381628.
# [I 2025-10-20 21:22:55,751] Trial 16 pruned.
# [I 2025-10-20 21:25:01,465] Trial 17 finished with value: 0.5182919837411033 and parameters: {'n_estimators': 800, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': 0.3, 'min_impurity_decrease': 0.0043708694911696565, 'max_samples': 0.6659280340479141, 'criterion': 'entropy'}. Best is trial 15 with value: 0.5366447413381628.
# [I 2025-10-20 21:28:37,348] Trial 18 finished with value: 0.5029873122549305 and parameters: {'n_estimators': 600, 'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 0.3, 'min_impurity_decrease': 0.0008210490446393433, 'max_samples': 0.9986991985846947, 'criterion': 'entropy'}. Best is trial 15 with value: 0.5366447413381628.
# [I 2025-10-20 21:29:30,268] Trial 19 finished with value: 0.536091789507145 and parameters: {'n_estimators': 800, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'log2', 'min_impurity_decrease': 0.0017637758367518848, 'max_samples': 0.7833201915860802, 'criterion': 'entropy'}. Best is trial 15 with value: 0.5366447413381628.
# [I 2025-10-20 21:29:53,447] Trial 20 pruned.
# [I 2025-10-20 21:30:19,662] Trial 21 pruned.
# [I 2025-10-20 21:31:57,628] Trial 22 finished with value: 0.4962989738699751 and parameters: {'n_estimators': 900, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'log2', 'min_impurity_decrease': 0.00012495507267083848, 'max_samples': 0.795795163509494, 'criterion': 'entropy'}. Best is trial 15 with value: 0.5366447413381628.
# [I 2025-10-20 21:32:42,816] Trial 23 pruned.
# [I 2025-10-20 21:35:04,322] Trial 24 finished with value: 0.5425415988698082 and parameters: {'n_estimators': 700, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 0.3, 'min_impurity_decrease': 0.002172336951946137, 'max_samples': 0.71234969178916, 'criterion': 'entropy'}. Best is trial 24 with value: 0.5425415988698082.
# [I 2025-10-20 21:35:53,022] Trial 25 finished with value: 0.5408253671090243 and parameters: {'n_estimators': 700, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'log2', 'min_impurity_decrease': 0.00149312086048888, 'max_samples': 0.7063242907935665, 'criterion': 'entropy'}. Best is trial 24 with value: 0.5425415988698082.
# [I 2025-10-20 21:36:59,690] Trial 26 pruned.
# [I 2025-10-20 21:37:33,004] Trial 27 finished with value: 0.538671212574397 and parameters: {'n_estimators': 600, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2', 'min_impurity_decrease': 0.0007457698831243081, 'max_samples': 0.6436598233770103, 'criterion': 'entropy'}. Best is trial 24 with value: 0.5425415988698082.
# [I 2025-10-20 21:38:27,978] Trial 28 finished with value: 0.5457340565526254 and parameters: {'n_estimators': 900, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'log2', 'min_impurity_decrease': 0.0007549377284725012, 'max_samples': 0.6382430485655266, 'criterion': 'entropy'}. Best is trial 28 with value: 0.5457340565526254.
# [I 2025-10-20 21:39:37,316] Trial 29 finished with value: 0.4984710263129591 and parameters: {'n_estimators': 900, 'max_depth': 13, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'log2', 'min_impurity_decrease': 4.472468779163539e-06, 'max_samples': 0.6303517454662704, 'criterion': 'gini'}. Best is trial 28 with value: 0.5457340565526254.
# [I 2025-10-20 21:40:02,216] Trial 30 pruned.
# [I 2025-10-20 21:40:44,826] Trial 31 finished with value: 0.5467742418887018 and parameters: {'n_estimators': 700, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'log2', 'min_impurity_decrease': 0.000529116876028057, 'max_samples': 0.6310473636509031, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 21:41:49,763] Trial 32 finished with value: 0.5139976656328126 and parameters: {'n_estimators': 700, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'log2', 'min_impurity_decrease': 0.000825881468953882, 'max_samples': 0.6224789192626252, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 21:42:18,404] Trial 33 pruned.
# [I 2025-10-20 21:42:32,983] Trial 34 pruned.
# [I 2025-10-20 21:48:35,039] Trial 35 finished with value: 0.5199718550534456 and parameters: {'n_estimators': 700, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.5, 'min_impurity_decrease': 0.0006164379812322711, 'max_samples': 0.601388721399245, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 21:49:34,009] Trial 36 pruned.
# [I 2025-10-20 21:50:07,918] Trial 37 finished with value: 0.5203702050953163 and parameters: {'n_estimators': 400, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'log2', 'min_impurity_decrease': 0.0011053977309606056, 'max_samples': 0.62750202756408, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 21:53:30,606] Trial 38 pruned.
# [I 2025-10-20 21:53:50,451] Trial 39 pruned.
# [I 2025-10-20 21:54:13,311] Trial 40 pruned.
# [I 2025-10-20 21:54:47,439] Trial 41 finished with value: 0.5397156388677568 and parameters: {'n_estimators': 600, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2', 'min_impurity_decrease': 0.0005504631892143349, 'max_samples': 0.6423331113148169, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 21:55:15,073] Trial 42 finished with value: 0.5392673818109799 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'log2', 'min_impurity_decrease': 0.0002840916618804788, 'max_samples': 0.6166830305192986, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 21:56:05,180] Trial 43 finished with value: 0.5438354554477556 and parameters: {'n_estimators': 700, 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 'log2', 'min_impurity_decrease': 0.001378937902552467, 'max_samples': 0.6922607922405675, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 21:56:33,891] Trial 44 pruned.
# [I 2025-10-20 22:02:05,094] Trial 45 finished with value: 0.5424244137496192 and parameters: {'n_estimators': 700, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 0.7, 'min_impurity_decrease': 0.0023313387597360493, 'max_samples': 0.7538410055415584, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 22:09:36,700] Trial 46 finished with value: 0.5391011634027003 and parameters: {'n_estimators': 1000, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': 0.7, 'min_impurity_decrease': 0.0025331076043445255, 'max_samples': 0.7531892172021447, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 22:12:51,163] Trial 47 pruned.
# [I 2025-10-20 22:16:54,612] Trial 48 pruned.
# [I 2025-10-20 22:18:17,943] Trial 49 pruned.
# [I 2025-10-20 22:26:22,985] Trial 50 finished with value: 0.5061414704197339 and parameters: {'n_estimators': 700, 'max_depth': 30, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 0.7, 'min_impurity_decrease': 0.0010953359350832725, 'max_samples': 0.8284143024929576, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 22:26:50,989] Trial 51 pruned.
# [I 2025-10-20 22:34:47,609] Trial 52 finished with value: 0.5105674994707492 and parameters: {'n_estimators': 800, 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.7, 'min_impurity_decrease': 0.0010937780237708977, 'max_samples': 0.7470854548463729, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 22:35:21,280] Trial 53 pruned.
# [I 2025-10-20 22:36:07,635] Trial 54 finished with value: 0.5178734197127233 and parameters: {'n_estimators': 600, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'log2', 'min_impurity_decrease': 0.0011857473846329557, 'max_samples': 0.6857588331535885, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 22:42:18,685] Trial 55 finished with value: 0.5091003586866043 and parameters: {'n_estimators': 800, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 0.5, 'min_impurity_decrease': 0.0006165554568088377, 'max_samples': 0.704060039964171, 'criterion': 'entropy'}. Best is trial 31 with value: 0.5467742418887018.
# [I 2025-10-20 22:43:58,227] Trial 56 finished with value: 0.5489503504165179 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.3, 'min_impurity_decrease': 0.0017984760535302118, 'max_samples': 0.7271756446316386, 'criterion': 'entropy'}. Best is trial 56 with value: 0.5489503504165179.
# [I 2025-10-20 22:44:33,364] Trial 57 pruned.
# [I 2025-10-20 22:45:37,740] Trial 58 pruned.
# [I 2025-10-20 22:46:36,622] Trial 59 pruned.
# [I 2025-10-20 22:47:26,609] Trial 60 finished with value: 0.5244921659434295 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.3, 'min_impurity_decrease': 0.00035215720633999145, 'max_samples': 0.7398955802452741, 'criterion': 'entropy'}. Best is trial 56 with value: 0.5489503504165179.
# [I 2025-10-20 22:47:50,877] Trial 61 pruned.
# [I 2025-10-20 22:50:42,765] Trial 62 finished with value: 0.5235877131174514 and parameters: {'n_estimators': 700, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.3, 'min_impurity_decrease': 0.0015937005704513378, 'max_samples': 0.7190777409866619, 'criterion': 'entropy'}. Best is trial 56 with value: 0.5489503504165179.
# [I 2025-10-20 22:51:22,429] Trial 63 finished with value: 0.518675895008496 and parameters: {'n_estimators': 400, 'max_depth': 21, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 'log2', 'min_impurity_decrease': 0.0012576474801467466, 'max_samples': 0.7493266142176991, 'criterion': 'entropy'}. Best is trial 56 with value: 0.5489503504165179.
# [I 2025-10-20 22:53:17,876] Trial 64 finished with value: 0.5431751116814246 and parameters: {'n_estimators': 600, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 0.3, 'min_impurity_decrease': 0.002215905929666242, 'max_samples': 0.6130869593657347, 'criterion': 'entropy'}. Best is trial 56 with value: 0.5489503504165179.
# [I 2025-10-20 22:54:13,903] Trial 65 pruned.
# [I 2025-10-20 22:56:57,618] Trial 66 finished with value: 0.5195074137656999 and parameters: {'n_estimators': 500, 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 0.3, 'min_impurity_decrease': 0.0008790619162135414, 'max_samples': 0.6403219196319604, 'criterion': 'entropy'}. Best is trial 56 with value: 0.5489503504165179.
# [I 2025-10-20 22:59:24,398] Trial 67 finished with value: 0.5436455283847645 and parameters: {'n_estimators': 600, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 0.3, 'min_impurity_decrease': 0.0021385398996287388, 'max_samples': 0.6689244319522302, 'criterion': 'entropy'}. Best is trial 56 with value: 0.5489503504165179.
# [I 2025-10-20 23:00:17,041] Trial 68 pruned.
# [I 2025-10-20 23:02:29,594] Trial 69 finished with value: 0.5408425571811243 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 0.3, 'min_impurity_decrease': 0.002082763503465629, 'max_samples': 0.9153800963349393, 'criterion': 'entropy'}. Best is trial 56 with value: 0.5489503504165179.
# [I 2025-10-20 23:02:57,453] Trial 70 pruned.
# [I 2025-10-20 23:03:45,866] Trial 71 pruned.
# [I 2025-10-20 23:04:44,558] Trial 72 pruned.
# [I 2025-10-20 23:07:12,718] Trial 73 finished with value: 0.5494187914517953 and parameters: {'n_estimators': 700, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 0.3, 'min_impurity_decrease': 0.001791724480505495, 'max_samples': 0.6722836972578319, 'criterion': 'entropy'}. Best is trial 73 with value: 0.5494187914517953.
# [I 2025-10-20 23:09:05,916] Trial 74 finished with value: 0.548044244268515 and parameters: {'n_estimators': 600, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.3, 'min_impurity_decrease': 0.0017652476428581124, 'max_samples': 0.6698808200451608, 'criterion': 'entropy'}. Best is trial 73 with value: 0.5494187914517953.
# [I 2025-10-20 23:10:38,706] Trial 75 finished with value: 0.5471591116301363 and parameters: {'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.3, 'min_impurity_decrease': 0.0018075072426639621, 'max_samples': 0.6690267859834534, 'criterion': 'entropy'}. Best is trial 73 with value: 0.5494187914517953.
# [I 2025-10-20 23:12:12,166] Trial 76 finished with value: 0.54769550443422 and parameters: {'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0017628915458026532, 'max_samples': 0.6717399507191446, 'criterion': 'entropy'}. Best is trial 73 with value: 0.5494187914517953.
# [I 2025-10-20 23:13:28,453] Trial 77 finished with value: 0.5295620221210512 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.00040626130176903163, 'max_samples': 0.656963491866139, 'criterion': 'entropy'}. Best is trial 73 with value: 0.5494187914517953.
# [I 2025-10-20 23:14:55,449] Trial 78 finished with value: 0.5504577969219111 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 0.3, 'min_impurity_decrease': 0.0009371855742260219, 'max_samples': 0.6950098012676854, 'criterion': 'entropy'}. Best is trial 78 with value: 0.5504577969219111.
# [I 2025-10-20 23:15:17,768] Trial 79 pruned.
# [I 2025-10-20 23:16:06,632] Trial 80 pruned.
# [I 2025-10-20 23:17:42,663] Trial 81 finished with value: 0.5523802995193003 and parameters: {'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.3, 'min_impurity_decrease': 0.0014261205925313564, 'max_samples': 0.6933133756279516, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:19:13,020] Trial 82 finished with value: 0.5501332060867895 and parameters: {'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.3, 'min_impurity_decrease': 0.0016279488189971571, 'max_samples': 0.6457058662830547, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:20:35,261] Trial 83 finished with value: 0.5444753125373756 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 0.3, 'min_impurity_decrease': 0.0016593481589587988, 'max_samples': 0.6490858853734778, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:21:54,605] Trial 84 finished with value: 0.5285339828933768 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.3, 'min_impurity_decrease': 4.295339592604394e-05, 'max_samples': 0.6849248331768997, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:22:37,687] Trial 85 pruned.
# [I 2025-10-20 23:24:23,313] Trial 86 finished with value: 0.5259726371343258 and parameters: {'n_estimators': 500, 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': 0.3, 'min_impurity_decrease': 0.001722336594774352, 'max_samples': 0.6607912203246804, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:25:32,367] Trial 87 finished with value: 0.5502236526642179 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0010037735644926509, 'max_samples': 0.6742507034284311, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:26:39,385] Trial 88 finished with value: 0.5504376041025963 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0009632434913287934, 'max_samples': 0.6755096397737118, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:28:07,874] Trial 89 finished with value: 0.503270347079603 and parameters: {'n_estimators': 300, 'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0008940693757581643, 'max_samples': 0.7057229132039303, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:29:16,103] Trial 90 finished with value: 0.549984564990127 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0010527556265365378, 'max_samples': 0.6788406869399806, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:30:23,203] Trial 91 finished with value: 0.549788776818171 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.001058267822199286, 'max_samples': 0.6773425642446983, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:30:49,831] Trial 92 pruned.
# [I 2025-10-20 23:31:57,203] Trial 93 finished with value: 0.552018281594026 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0005475861445430118, 'max_samples': 0.6912182038108713, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:33:05,271] Trial 94 finished with value: 0.5517354855628374 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0003038246675414804, 'max_samples': 0.6929099817788761, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:34:13,806] Trial 95 finished with value: 0.5517507547141254 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.00027901464445600067, 'max_samples': 0.6949362070620699, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:35:21,640] Trial 96 finished with value: 0.5515788586408304 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.3, 'min_impurity_decrease': 0.0002095156526906381, 'max_samples': 0.6941436728470148, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.
# [I 2025-10-20 23:35:34,101] Trial 97 pruned.
# [I 2025-10-20 23:36:08,756] Trial 98 pruned.
# [I 2025-10-20 23:37:16,805] Trial 99 finished with value: 0.5512604183695186 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.3, 'min_impurity_decrease': 0.00011060801304088431, 'max_samples': 0.6927204694156763, 'criterion': 'entropy'}. Best is trial 81 with value: 0.5523802995193003.

# %%
best_params = study.best_params
best_score = study.best_value

print(f"best cross-validated AUCPR: {best_score:.4f}")
print(f"best parameters:")
for param, value in sorted(best_params.items()):
    print(f"  {param}: {value}")

best_trial = study.best_trial
print(f"\nbest trial details:")
print(f"  training set average AUC: {best_trial.user_attrs['mean_train_auc']:.4f}")
print(f"  test set average AUC: {best_trial.user_attrs['mean_val_auc']:.4f}")
print(f"  test set average AUCPR: {best_trial.user_attrs['mean_val_aucpr']:.4f}")
print(f"  Overfitting gap: {best_trial.user_attrs['overfitting_gap']:.4f}")
# Out:
# best cross-validated AUCPR: 0.5524
# best parameters:
#   criterion: entropy
#   max_depth: 7
#   max_features: 0.3
#   max_samples: 0.6933133756279516
#   min_impurity_decrease: 0.0014261205925313564
#   min_samples_leaf: 2
#   min_samples_split: 10
#   n_estimators: 500
#
# best trial details:
#   training set average AUC: 0.8784
#   test set average AUC: 0.8340
#   test set average AUCPR: 0.5524
#   Overfitting gap: 0.0445

# %%
best_rf = RandomForestClassifier(
    class_weight='balanced',
    bootstrap=True,
    oob_score=True,
    random_state=42,
    n_jobs=-1,
    **best_params
)

best_rf.fit(X_train_imputed, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=7, max_features=0.3,
#                        max_samples=0.6933133756279516,
#                        min_impurity_decrease=0.0014261205925313564,
#                        min_samples_leaf=2, min_samples_split=10,
#                        n_estimators=500, n_jobs=-1, oob_score=True,
#                        random_state=42)

# %% [markdown]
# ## 7. Model Evaluation

# %%
y_train_pred = best_rf.predict(X_train_imputed)
y_test_pred = best_rf.predict(X_test_imputed)
y_train_proba = best_rf.predict_proba(X_train_imputed)[:, 1]
y_test_proba = best_rf.predict_proba(X_test_imputed)[:, 1]

# Training set performance
print("Training set performance:")
train_auc = roc_auc_score(y_train, y_train_proba)
train_acc = best_rf.score(X_train_imputed, y_train)
print(f"  Accuracy: {train_acc:.4f}")
print(f"  AUC-ROC: {train_auc:.4f}")
print(f"  AUPRC: {average_precision_score(y_train, y_train_proba):.4f}")
print(classification_report(y_train, y_train_pred))

# Test set performance
print("\nTest set performance:")
test_auc = roc_auc_score(y_test, y_test_proba)
test_acc = best_rf.score(X_test_imputed, y_test)
print(f"  Accuracy: {test_acc:.4f}")
print(f"  AUC-ROC: {test_auc:.4f}")
print(f"  AUPRC: {average_precision_score(y_test, y_test_proba):.4f}")
print(classification_report(y_test, y_test_pred))
# Out:
# Training set performance:
#   Accuracy: 0.7989
#   AUC-ROC: 0.8660
#   AUPRC: 0.6047
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87     19421
#            1       0.44      0.75      0.55      3827
#
#     accuracy                           0.80     23248
#    macro avg       0.69      0.78      0.71     23248
# weighted avg       0.86      0.80      0.82     23248
#
#
# Test set performance:
#   Accuracy: 0.7927
#   AUC-ROC: 0.8464
#   AUPRC: 0.5764
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      4855
#            1       0.42      0.71      0.53       957
#
#     accuracy                           0.79      5812
#    macro avg       0.68      0.76      0.70      5812
# weighted avg       0.85      0.79      0.81      5812

# %%
# Overfitting check
print(f"\nOverfitting analysis:")
print(f"  Train-Test AUC difference: {(train_auc - test_auc):.4f}")
if train_auc - test_auc < 0.05:
    print(f"Low overfitting (difference < 0.05)")
elif train_auc - test_auc < 0.10:
    print(f"Mild overfitting (difference 0.05-0.10)")
else:
    print(f"Significant overfitting (difference > 0.10)")

# Confusion matrix
print("\nConfusion Matrix (Test Set):")
cm = confusion_matrix(y_test, y_test_pred)
print(f"  True Negative (TN): {cm[0,0]}, False Positive (FP): {cm[0,1]}")
print(f"  False Negative (FN): {cm[1,0]}, True Positive (TP): {cm[1,1]}")

# Calculate additional metrics
sensitivity = cm[1,1] / (cm[1,1] + cm[1,0])  # Recall/Sensitivity
specificity = cm[0,0] / (cm[0,0] + cm[0,1])  # Specificity
precision = cm[1,1] / (cm[1,1] + cm[0,1])    # Precision
npv = cm[0,0] / (cm[0,0] + cm[1,0])          # Negative Predictive Value

print(f"\nDetailed Performance Metrics:")
print(f"  Sensitivity (Recall): {sensitivity:.3f}")
print(f"  Specificity: {specificity:.3f}")
print(f"  Precision: {precision:.3f}")
print(f"  Negative Predictive Value (NPV): {npv:.3f}")
# Out:
# Overfitting analysis:
#   Train-Test AUC difference: 0.0196
# Low overfitting (difference < 0.05)
#
# Confusion Matrix (Test Set):
#   True Negative (TN): 3925, False Positive (FP): 930
#   False Negative (FN): 275, True Positive (TP): 682
#
# Detailed Performance Metrics:
#   Sensitivity (Recall): 0.713
#   Specificity: 0.808
#   Precision: 0.423
#   Negative Predictive Value (NPV): 0.935

# %% [markdown]
# ## 8. Feature Importance Analysis

# %%
# Random Forest feature importance (based on mean impurity decrease)
feature_names = X.columns.tolist()
feature_importance = best_rf.feature_importances_

importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importance
}).sort_values('importance', ascending=False)

print(f"\nTop 20 Most Important Features:")
for i, row in importance_df.head(20).iterrows():
    print(f"{row['feature']:30s}: {row['importance']:.6f}")

# Cumulative importance analysis
importance_df['cumulative_importance'] = importance_df['importance'].cumsum()
n_features_90 = (importance_df['cumulative_importance'] <= 0.90).sum()
n_features_95 = (importance_df['cumulative_importance'] <= 0.95).sum()

print(f"\nCumulative Feature Importance Analysis:")
print(f"  Top {n_features_90} features contribute 90% of importance")
print(f"  Top {n_features_95} features contribute 95% of importance")
print(f"  Total number of features: {len(feature_names)}")
# Out:
# Top 20 Most Important Features:
# SOFA_mean                     : 0.110035
# GCS_last                      : 0.094098
# SOFA_last                     : 0.076280
# output_step_mean              : 0.073070
# median_dose_vaso_last         : 0.052965
# FiO2_100_last                 : 0.043686
# FiO2_1_last                   : 0.043092
# SOFA_min                      : 0.037589
# age                           : 0.031140
# BUN_last                      : 0.030545
# elixhauser                    : 0.027140
# Arterial_lactate_last         : 0.025312
# Arterial_lactate_mean         : 0.024698
# SIRS_mean                     : 0.023889
# O2flow_last                   : 0.023487
# Shock_Index_last              : 0.021406
# GCS_max                       : 0.020270
# output_step_std               : 0.018798
# Arterial_lactate_min          : 0.014957
# FiO2_100_min                  : 0.011294
#
# Cumulative Feature Importance Analysis:
#   Top 32 features contribute 90% of importance
#   Top 46 features contribute 95% of importance
#   Total number of features: 85

# %% [markdown]
# ## 9. Visualization

# %%
fig_optuna = plt.figure(figsize=(16, 10))
gs_optuna = fig_optuna.add_gridspec(3, 2, hspace=0.3, wspace=0.3)

# 1. optimization history
ax1 = fig_optuna.add_subplot(gs_optuna[0, 0])
trial_numbers = [trial.number for trial in study.trials]
trial_values = [trial.value if trial.value is not None else 0 for trial in study.trials]
best_values = [study.best_value if i == 0 else max(study.best_value, max(trial_values[:i+1])) 
               for i in range(len(trial_values))]

ax1.plot(trial_numbers, trial_values, marker='o', alpha=0.6, label='Trial Value', color='#3498db')
ax1.plot(trial_numbers, best_values, linewidth=2, label='Best Value', color='#e74c3c')
ax1.set_xlabel('Trial Number', fontweight='bold')
ax1.set_ylabel('AUCPR', fontweight='bold')
ax1.set_title('Optimization History', fontsize=12, fontweight='bold')
ax1.legend()
ax1.grid(True, alpha=0.3)

# 2. parameter importance
ax2 = fig_optuna.add_subplot(gs_optuna[0, 1])
try:
    importances = optuna.importance.get_param_importances(study)
    param_names = list(importances.keys())
    importance_values = list(importances.values())
    
    top_n = min(8, len(param_names))
    param_names = param_names[:top_n]
    importance_values = importance_values[:top_n]
    
    colors = plt.cm.viridis(np.linspace(0.3, 0.9, len(param_names)))
    ax2.barh(range(len(param_names)), importance_values, color=colors, edgecolor='black')
    ax2.set_yticks(range(len(param_names)))
    ax2.set_yticklabels(param_names)
    ax2.set_xlabel('Importance', fontweight='bold')
    ax2.set_title('Hyperparameter Importance', fontsize=12, fontweight='bold')
    ax2.invert_yaxis()
    ax2.grid(True, axis='x', alpha=0.3)
except:
    ax2.text(0.5, 0.5, 'Not enough trials for importance analysis', 
             ha='center', va='center', transform=ax2.transAxes, fontsize=12)

# 3. overfitting analysis(AUCPR)
ax3 = fig_optuna.add_subplot(gs_optuna[1, :])
train_aucs = [trial.user_attrs.get('mean_train_auc', 0) for trial in study.trials]
val_aucprs = [trial.user_attrs.get('mean_val_aucpr', 0) for trial in study.trials]
trial_numbers = range(len(study.trials))

ax3.plot(trial_numbers, train_aucs, label='Train AUC', alpha=0.6, color='#3498db')
ax3.plot(trial_numbers, val_aucprs, label='Validation AUCPR', alpha=0.6, color='#e74c3c')
ax3.axhline(y=best_score, color='green', linestyle='--', 
            label=f'Best Val AUCPR: {best_score:.4f}', linewidth=2)
ax3.set_xlabel('Trial Number')
ax3.set_ylabel('Score')
ax3.set_title('Train AUC vs Validation AUCPR Across Trials', fontsize=12, fontweight='bold')
ax3.legend()
ax3.grid(True, alpha=0.3)

# 4. Learning Rate vs Max Depth scatter plot
ax4 = fig_optuna.add_subplot(gs_optuna[2, 0])
lr_values = [trial.params.get('learning_rate', 0) for trial in study.trials]
depth_values = [trial.params.get('max_depth', 0) for trial in study.trials]
val_aucprs_scatter = [trial.user_attrs.get('mean_val_aucpr', 0) for trial in study.trials]
scatter = ax4.scatter(lr_values, depth_values, c=val_aucprs_scatter, 
                     cmap='RdYlGn', s=100, alpha=0.6, edgecolors='black')
ax4.set_xlabel('Learning Rate')
ax4.set_ylabel('Max Depth')
ax4.set_title('Learning Rate vs Max Depth (colored by Val AUCPR)', 
              fontsize=12, fontweight='bold')
plt.colorbar(scatter, ax=ax4, label='Validation AUCPR')
ax4.grid(True, alpha=0.3)

# 5. Overfitting gap distribution
ax5 = fig_optuna.add_subplot(gs_optuna[2, 1])
overfitting_gaps = [trial.user_attrs.get('overfitting_gap', 0) for trial in study.trials]
ax5.hist(overfitting_gaps, bins=30, color='#e74c3c', alpha=0.7, edgecolor='black')
ax5.axvline(x=0.05, color='red', linestyle='--', 
            label='Overfitting Threshold (0.05)', linewidth=2)
ax5.set_xlabel('Overfitting Gap (Train AUC - Val AUC)')
ax5.set_ylabel('Frequency')
ax5.set_title('Distribution of Overfitting Gap', fontsize=12, fontweight='bold')
ax5.legend()
ax5.grid(True, alpha=0.3, axis='y')

plt.suptitle('Optuna Hyperparameter Optimization Analysis', 
             fontsize=16, fontweight='bold', y=0.995)
plt.show()

# %%
fig = plt.figure(figsize=(20, 20))
gs = fig.add_gridspec(4, 3, hspace=0.35, wspace=0.3)

# 1. Confusion Matrix
ax1 = fig.add_subplot(gs[0, 0])
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', ax=ax1,
            xticklabels=['Survived', 'Died'], 
            yticklabels=['Survived', 'Died'],
            cbar_kws={'label': 'Count'})
ax1.set_title('Confusion Matrix (Test Set)', fontsize=12, fontweight='bold')
ax1.set_xlabel('Predicted Label')
ax1.set_ylabel('True Label')

# 2. ROC Curve
ax2 = fig.add_subplot(gs[0, 1])
fpr, tpr, thresholds = roc_curve(y_test, y_test_proba)
ax2.plot(fpr, tpr, label=f'Random Forest (AUC={test_auc:.3f})', 
         linewidth=2.5, color='#27ae60')
ax2.plot([0, 1], [0, 1], 'k--', label='Random Guess', alpha=0.5)
ax2.fill_between(fpr, tpr, alpha=0.2, color='#27ae60')
ax2.set_xlabel('False Positive Rate (FPR)')
ax2.set_ylabel('True Positive Rate (TPR)')
ax2.set_title('ROC Curve', fontsize=12, fontweight='bold')
ax2.legend(loc='lower right')
ax2.grid(True, alpha=0.3)

# 3. Train vs Test vs OOB Comparison
ax3 = fig.add_subplot(gs[0, 2])
scores = [train_auc, test_auc, best_rf.oob_score_]
labels = ['Train', 'Test', 'OOB']
colors = ['#3498db', '#e74c3c', '#f39c12']
bars = ax3.bar(labels, scores, color=colors, alpha=0.7, edgecolor='black', linewidth=2)
ax3.set_ylabel('AUC Score', fontweight='bold')
ax3.set_title('Model Performance Comparison', fontsize=12, fontweight='bold')
ax3.set_ylim([0.5, 1.0])
for bar, score in zip(bars, scores):
    height = bar.get_height()
    ax3.text(bar.get_x() + bar.get_width()/2., height,
             f'{score:.3f}', ha='center', va='bottom', 
             fontweight='bold', fontsize=11)
ax3.grid(True, alpha=0.3, axis='y')

# 4. Top 20 Feature Importance
ax4 = fig.add_subplot(gs[1, :])
top20 = importance_df.head(20)
colors_feat = plt.cm.YlGn(np.linspace(0.4, 0.9, len(top20)))
bars = ax4.barh(range(len(top20)), top20['importance'], color=colors_feat, 
                edgecolor='black', linewidth=0.5)
ax4.set_yticks(range(len(top20)))
ax4.set_yticklabels(top20['feature'])
ax4.set_xlabel('Feature Importance (Mean Impurity Decrease)', fontweight='bold')
ax4.set_title('Top 20 Feature Importance - Random Forest', 
              fontsize=12, fontweight='bold')
ax4.invert_yaxis()
ax4.grid(True, axis='x', alpha=0.3)

# 5. Prediction Probability Distribution
ax5 = fig.add_subplot(gs[2, 0])
ax5.hist(y_test_proba[y_test==0], bins=30, alpha=0.7, 
         label='Survived Patients', density=True, color='#3498db', edgecolor='black')
ax5.hist(y_test_proba[y_test==1], bins=30, alpha=0.7, 
         label='Died Patients', density=True, color='#e74c3c', edgecolor='black')
ax5.axvline(x=0.5, color='green', linestyle='--', linewidth=2, label='Default Threshold')
ax5.set_xlabel('Predicted Death Probability', fontweight='bold')
ax5.set_ylabel('Density', fontweight='bold')
ax5.set_title('Prediction Probability Distribution', fontsize=12, fontweight='bold')
ax5.legend()
ax5.grid(True, alpha=0.3)

# 6. Cumulative Feature Importance
ax6 = fig.add_subplot(gs[2, 1])
ax6.plot(range(1, len(importance_df)+1), 
         importance_df['cumulative_importance'].values,
         linewidth=2.5, color='#27ae60')
ax6.axhline(y=0.90, color='red', linestyle='--', linewidth=2, label='90%')
ax6.axhline(y=0.95, color='orange', linestyle='--', linewidth=2, label='95%')
ax6.axvline(x=n_features_90, color='red', linestyle=':', alpha=0.5)
ax6.axvline(x=n_features_95, color='orange', linestyle=':', alpha=0.5)
ax6.set_xlabel('Number of Features', fontweight='bold')
ax6.set_ylabel('Cumulative Importance', fontweight='bold')
ax6.set_title('Cumulative Feature Importance Curve', fontsize=12, fontweight='bold')
ax6.legend()
ax6.grid(True, alpha=0.3)
ax6.text(n_features_90, 0.5, f'n={n_features_90}', rotation=90, va='bottom')

# 7. Performance Metrics Radar Chart
ax7 = fig.add_subplot(gs[2, 2], projection='polar')
categories = ['AUC', 'Accuracy', 'Sensitivity', 'Specificity', 'Precision']
values = [test_auc, test_acc, sensitivity, specificity, precision]
angles = np.linspace(0, 2 * np.pi, len(categories), endpoint=False).tolist()
values += values[:1]
angles += angles[:1]
ax7.plot(angles, values, 'o-', linewidth=2, color='#27ae60')
ax7.fill(angles, values, alpha=0.25, color='#27ae60')
ax7.set_xticks(angles[:-1])
ax7.set_xticklabels(categories)
ax7.set_ylim(0, 1)
ax7.set_title('Performance Metrics Radar Chart', fontsize=12, fontweight='bold', pad=20)
ax7.grid(True)
